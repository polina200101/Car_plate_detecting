# %%
# Копируем папки train и val в нужную директорию
# !mkdir -p /kaggle/working/dataset
# !cp -r /kaggle/input/wheel-balancing-screen-detection/content/train /kaggle/working/dataset/
# !cp -r /kaggle/input/wheel-balancing-screen-detection/content/val /kaggle/working/dataset/
# !cp -r /kaggle/input/wheel-balancing-screen-detection/content/test /kaggle/working/dataset/

# %%
# Установка необходимых зависимостей
# !pip install ultralytics
# !pip install torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.2 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.3 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# Если это папка, используйте рекурсивное удаление
# !rm -rf /kaggle/working/yolo-9-detection-training

# %%
# Установка переменной окружения для лучшего управления памятью CUDA
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# Клонирование вашего репозитория
# !git clone https://github.com/luxa2754/Car_plate_detecting.git

# Запуск обучения
import sys
sys.path.append('/kaggle/working/Car_plate_detecting')

from yolo9_train import train
import configparser

conf = configparser.ConfigParser()
conf.read("/kaggle/working/Car_plate_detecting/Config/Config.ini")
train(conf["Train"])
# Out:
# Cloning into 'Car_plate_detecting'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 74 (delta 9), reused 66 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 8.96 MiB | 28.42 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.200 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
